# %%
import geopandas as gpd
import mapclassify
import libpysal
import seaborn as sns
sns.set_theme(style='dark')

# %% [markdown]
# ## Liste de tous les exemples dipo sur libpysal

# %%
libpysal.examples.available()
# Out:
#          Name                                        Description  Installed
# 0       10740  Albuquerque, New Mexico, Census 2000 Tract Dat...       True
# 1      AirBnB  Airbnb rentals, socioeconomics, and crime in C...      False
# 2     Atlanta       Atlanta, GA region homicide counts and rates      False
# 3   Baltimore          Baltimore house sales prices and hedonics      False
# 4   Bostonhsg               Boston housing and neighborhood data      False
# ..        ...                                                ...        ...
# 93        taz           Traffic Analysis Zones in So. California      False
# 94      tokyo                               Tokyo Mortality data       True
# 95  us_income  Per-capita income for the lower 48 US states 1...       True
# 96   virginia                        Virginia counties shapefile       True
# 97       wmat          Datasets used for spatial weights testing       True
#
# [98 rows x 3 columns]

# %%
_ = libpysal.examples.load_example('South')
pth = libpysal.examples.get_path('south.shp')

# %%
south = gpd.read_file(pth)
south
# Out:
#                 NAME     STATE_NAME STATE_FIPS CNTY_FIPS   FIPS  STFIPS  \
# 0            Hancock  West Virginia         54       029  54029      54
# 1             Brooke  West Virginia         54       009  54009      54
# 2               Ohio  West Virginia         54       069  54069      54
# 3           Marshall  West Virginia         54       051  54051      54
# 4         New Castle       Delaware         10       003  10003      10
# ...              ...            ...        ...       ...    ...     ...
# 1407         Halifax       Virginia         51       083  51083      51
# 1408      Rockbridge       Virginia         51       163  51163      51
# 1409         Roanoke       Virginia         51       161  51161      51
# 1410            York       Virginia         51       199  51199      51
# 1411  Prince William       Virginia         51       153  51153      51
#
#       COFIPS  FIPSNO  SOUTH       HR60  ...      BLK90      GI59      GI69  \
# ...

# %%
ax = south.plot(column='HR60', scheme='QUANTILES', k=4, \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5)})

# %% [markdown]
# On prend la légende

# %%
labels = [t.get_text() for t in ax.get_legend().get_texts()]
labels
# Out:
# [' 0.00,  3.21', ' 3.21,  6.25', ' 6.25,  9.96', ' 9.96, 92.94']

# %% [markdown]
# On tire les quantiles extrait par mapclassify

# %%
q4 = mapclassify.Quantiles(south.HR60, k=4)
q4
# Out:
# Quantiles
#
#    Interval      Count
# ----------------------
# [ 0.00,  3.21] |   353
# ( 3.21,  6.25] |   353
# ( 6.25,  9.96] |   353
# ( 9.96, 92.94] |   353

# %%
labels == q4.get_legend_classes()
# Out:
# False

# %% [markdown]
# ### Chqnger le format numérique de la légende

# %%
ax = south.plot(column='HR60', scheme='QUANTILES', k=4, \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),  'fmt':"{:.4f}"}) # C'est grace au fmt

# %%
ax = south.plot(column='HR60', scheme='QUANTILES', k=4, \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),  'fmt':"{:.0f}"})

# %% [markdown]
# ### Pour voir les crochets des intervalles

# %%
ax = south.plot(column='HR60', scheme='BoxPlot', \
             cmap='BuPu', legend=True,
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),
                         'interval': True}) # parametre interval

# %% [markdown]
# ## Données catégorique

# %% [markdown]
# Par exemple les noms des états ou des villes

# %%
ax = south.plot(column='STATE_NAME', categorical=True, legend=True, \
             legend_kwds={'loc': 'center left', 'bbox_to_anchor':(1,0.5),
                         'fmt': "{:.0f}"}) # fmt is ignored for categorical data
